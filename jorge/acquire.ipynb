# %%
#tabular data imports :
import pandas as pd
import numpy as np
from pydataset import data

# visualization imports:
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# success metrics from earlier in the week: mean squared error and r^2 explained variance
from sklearn.preprocessing import MinMaxScaler, PolynomialFeatures

#stats
from scipy.stats import pearsonr, spearmanr
from scipy.stats import shapiro

import warnings
warnings.filterwarnings("ignore")
import wrangle as w
import os
directory = os.getcwd()
pd.set_option('display.max_columns', None)

# %%
df_red = pd.read_csv('https://query.data.world/s/qgc7p446ulzlgtja2626fwkzcm6ttf?dws=00000')
df_white = pd.read_csv('https://query.data.world/s/f5oqq5ltnxcdnoh7uykzubtxnnspne?dws=00000')

# %%
df_red.head(3)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5

# %%
df_white.head(3)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6

# %%
# Create a new index column
df_red['wine_id'] = ['red-' + str(i) for i in range(1, len(df_red) + 1)]

# Set this new column as the index
df_red = df_red.set_index('wine_id')

# %%
df_red.head(3)
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# wine_id
# red-1              7.4              0.70         0.00             1.9
# red-2              7.8              0.88         0.00             2.6
# red-3              7.8              0.76         0.04             2.3
#
#          chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# wine_id
# red-1        0.076                 11.0                  34.0   0.9978  3.51
# red-2        0.098                 25.0                  67.0   0.9968  3.20
# red-3        0.092                 15.0                  54.0   0.9970  3.26
#
#          sulphates  alcohol  quality
# wine_id
# red-1         0.56      9.4        5
# red-2         0.68      9.8        5
# red-3         0.65      9.8        5

# %%
# Create a new index column
df_white['wine_id'] = ['white-' + str(i) for i in range(1, len(df_white) + 1)]

# Set this new column as the index
df_white = df_white.set_index('wine_id')

# %%
df_white.head(3)
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# wine_id
# white-1            7.0              0.27         0.36            20.7
# white-2            6.3              0.30         0.34             1.6
# white-3            8.1              0.28         0.40             6.9
#
#          chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# wine_id
# white-1      0.045                 45.0                 170.0   1.0010  3.00
# white-2      0.049                 14.0                 132.0   0.9940  3.30
# white-3      0.050                 30.0                  97.0   0.9951  3.26
#
#          sulphates  alcohol  quality
# wine_id
# white-1       0.45      8.8        6
# white-2       0.49      9.5        6
# white-3       0.44     10.1        6

# %%
# Concatenate the DataFrames horizontally
df = pd.concat([df_white, df_red], axis=0)

# %%
df.head(3)
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# wine_id
# white-1            7.0              0.27         0.36            20.7
# white-2            6.3              0.30         0.34             1.6
# white-3            8.1              0.28         0.40             6.9
#
#          chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# wine_id
# white-1      0.045                 45.0                 170.0   1.0010  3.00
# white-2      0.049                 14.0                 132.0   0.9940  3.30
# white-3      0.050                 30.0                  97.0   0.9951  3.26
#
#          sulphates  alcohol  quality
# wine_id
# white-1       0.45      8.8        6
# white-2       0.49      9.5        6
# white-3       0.44     10.1        6

# %%
df.quality.value_counts()
# Out:
# 6    2836
# 5    2138
# 7    1079
# 4     216
# 8     193
# 3      30
# 9       5
# Name: quality, dtype: int64

# %%
# Call the function and get the combined DataFrame
df = w.load_and_prepare_wine_data(w.red_wine_url, w.white_wine_url)

# %%
df.head()
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# wine_id
# white-1            7.0              0.27         0.36            20.7
# white-2            6.3              0.30         0.34             1.6
# white-3            8.1              0.28         0.40             6.9
# white-4            7.2              0.23         0.32             8.5
# white-5            7.2              0.23         0.32             8.5
#
#          chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# wine_id
# white-1      0.045                 45.0                 170.0   1.0010  3.00
# white-2      0.049                 14.0                 132.0   0.9940  3.30
# white-3      0.050                 30.0                  97.0   0.9951  3.26
# white-4      0.058                 47.0                 186.0   0.9956  3.19
# white-5      0.058                 47.0                 186.0   0.9956  3.19
#
#          sulphates  alcohol  quality
# wine_id
# white-1       0.45      8.8        6
# white-2       0.49      9.5        6
# white-3       0.44     10.1        6
# white-4       0.40      9.9        6
# white-5       0.40      9.9        6
